# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive/MyDrive/
# Out:
#  business.gdoc			    'personal statement.gdoc'
#  cities.gdoc			    "PTSD and it's effects .gdoc"
# 'Colab Notebooks'		    'Silent voices 2.gdoc'
#  Commentary.gdoc		     Summary.gdoc
# 'Copy of season1episode1.srt'	    'Untitled document (1).gdoc'
#  distilbert_base_squad_model_final  'Untitled document (2).gdoc'
# 'Educational app .gdoc'		    'Untitled document.gdoc'
#  fiction.gdoc			    'Новый рисунок (1).gdraw'
#  jordan.gdoc			    'Новый рисунок.gdraw'
#  model.safetensors

# %%
from huggingface_hub import login
# !pip install -U datasets
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.5/491.5 kB 8.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 20.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.2
#     Uninstalling fsspec-2025.3.2:
#       Successfully uninstalled fsspec-2025.3.2
#   Attempting uninstall: datasets
#     Found existing installation: datasets 2.14.4
#     Uninstalling datasets-2.14.4:
#       Successfully uninstalled datasets-2.14.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2025.3.0 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cublas-cu12==12.4.5.8; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cublas-cu12 12.5.3.2 which is incompatible.
# ...

# %%
# authenticate HF access
HF_TOKEN = os.getenv("HF_TOKEN")

# %%
from datasets import load_dataset

# download the validation split of SQuAD adversarial w cache handling
newsqa = load_dataset(
    "squad_adversarial",
    "AddSent",
    split="validation",
    cache_dir="/content/hf_cache",           # avoid LocalFileSystem issue
    download_mode="force_redownload"         # force fresh download
)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md:   0%|          | 0.00/8.54k [00:00<?, ?B/s]
# squad_adversarial.py:   0%|          | 0.00/5.74k [00:00<?, ?B/s]
# squad_adversarial.py:   0%|          | 0.00/5.74k [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/8.54k [00:00<?, ?B/s]
# The repository for squad_adversarial contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/squad_adversarial.
# ...

# %%
# !pip install -U transformers datasets huggingface_hub

# %%
from transformers import pipeline, AutoTokenizer, AutoModelForQuestionAnswering

model_path = "/content/drive/MyDrive/distilbert_base_squad_model_final"

tokenizer = AutoTokenizer.from_pretrained(model_path)
model = AutoModelForQuestionAnswering.from_pretrained(model_path)

question_answerer = pipeline("question-answering", model=model, tokenizer=tokenizer)
# Out:
# Device set to use cuda:0

# %%
for sample in newsqa.select(range(5)):  # or random samples
    question = sample["question"]
    context = sample["context"]
    answer = question_answerer(question=question, context=context)
    print(f"Q: {question}")
    print(f"A: {answer['answer']}\n")
# Out:
# Q: Where did Super Bowl 50 take place?
# A: Santa Clara, California
#
# Q: What day was the Super Bowl played on?
# A: February 7, 2016
#
# Q: What venue did Super Bowl 50 take place in?
# A: Levi's Stadium
#
# Q: What year did the Denver Broncos secure a Super Bowl title for the third time?
# A: 2016
#
# Q: What was the final score of Super Bowl 50?
# A: Super Bowl 50 was an American football game
